# %%
# %matplotlib inline
# %run helper_functions.py
import pandas as pd
import seaborn as sns
import numpy as np
import sklearn
sns.set_style("whitegrid")
#pylab.rcParams['figure.figsize'] = 16, 12

# %% [markdown]
# # LOAD IRIS DATASET

# %%
from sklearn import datasets
iris = datasets.load_iris()

# %%
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df['species'] = iris.target_names[iris.target]
sns.pairplot(iris_df, hue="species", size=3 ,diag_kind="kde")
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
X = iris.data
feature_names = iris.feature_names
y = iris.target
class_labels = iris.target_names

# %% [markdown]
# ### experimenting with n_clusters

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score, silhouette_score

clustering = KMeans(n_clusters= 6).fit(X) # play with N
labels = clustering.labels_
iris_df.loc[:,'species'] = ["Class: " + str(x) for x in labels]

print ("Adjusted rand score: ", adjusted_rand_score(y, labels)  )
print ("Silhoutte score: ", silhouette_score(X, labels, metric='euclidean') )
       
sns.pairplot(iris_df, hue="species", size=3 ,diag_kind="kde")
plt.show()
# Out:
# Adjusted rand score:  0.6236058199496589
# Silhoutte score:  0.4764222301130771
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Metrics and selecting number of clusters

# %%
from sklearn.cluster import KMeans

scores = []
for k in range (1, 10):
    kmeans = KMeans(n_clusters= k).fit(X)
    score = kmeans.score(X)
    scores.append((k,score))
    
scores = np.array(scores)
plt.plot(scores[:,0], scores[:,1],  marker='o')

# %% [markdown]
# # Spectral clustering

# %%
from sklearn.cluster import SpectralClustering
from sklearn.metrics import adjusted_rand_score, silhouette_score

clustering = SpectralClustering().fit(X)
labels = clustering.labels_
iris_df.loc[:,'species'] = ["Class: " + str(x) for x in labels]

print ("Adjusted rand score: ", adjusted_rand_score(y, labels)  )
print ("Silhoutte score: ", silhouette_score(X, labels, metric='euclidean') )
       
sns.pairplot(iris_df, hue="species", size=3 ,diag_kind="kde")
plt.show()
# Out:
# Adjusted rand score:  0.47999581014231235
# Silhoutte score:  0.3428783614670446
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # DBSCAN

# %%
from sklearn.cluster import DBSCAN
from sklearn.metrics import adjusted_rand_score, silhouette_score

clustering = DBSCAN().fit(X)
labels = clustering.labels_
iris_df.loc[:,'species'] = ["Class: " + str(x) for x in labels]

print ("Adjusted rand score: ", adjusted_rand_score(y, labels)  )
print ("Silhoutte score: ", silhouette_score(X, labels, metric='euclidean') )
       
sns.pairplot(iris_df, hue="species", size=3 ,diag_kind="kde")
plt.show()
# Out:
# Adjusted rand score:  0.5206185241703302
# Silhoutte score:  0.48603419703456857
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
